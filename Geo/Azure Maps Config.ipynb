# %% [markdown]
# > Gather Azure Maps Key from Key Vault

# %%
help(dbutils.secrets)

# %%
### List secrets in a particular "mount"
dbutils.secrets.list("mount")

# %%
### get a particular secret from a given "mount"
dbutils.secrets.get("mount")
